# %%
import numpy as np
import pandas as pd
import os
import yaml
import matplotlib.pyplot as plt
import torch

from utils import *
from train import Net

pd.set_option('display.max_columns', 15)  # Adjust the number as needed
pd.set_option('display.expand_frame_repr', False)  # Disable automatic wrapping

# %%
# exp_id = ["122", "123", "124", "125", "126", "127", "128"]
exp_id = '128'
exp_dir = create_exp_folder(exp_id)
print("Experiment folder: ", exp_dir)
# Out:
# Experiment ID: 128
# Experiment folder:  experiments/128

# %%
# get the list of runs within the experiment folder
runs = os.listdir(exp_dir)
runs = [run for run in runs if os.path.isdir(os.path.join(exp_dir, run))] # filter out files
[print(run) for run in runs]; #! remove
# Out:
# lr_0_05_hdim_32_lay_2_rate_0_4_sched_CAWR
# lr_0_1_hdim_16_lay_2_rate_0_0_sched_Cycl
# lr_0_1_hdim_64_lay_2_rate_0_0_sched_CAWR
# lr_0_05_hdim_16_lay_1_rate_0_4_sched_Cycl
# lr_0_1_hdim_64_lay_1_rate_0_4_sched_Cycl
# lr_0_05_hdim_16_lay_2_rate_0_4_sched_Cycl
# lr_0_1_hdim_32_lay_1_rate_0_0_sched_Cycl
# lr_0_05_hdim_64_lay_2_rate_0_0_sched_CAWR
# lr_0_05_hdim_32_lay_2_rate_0_2_sched_CAWR
# lr_0_01_hdim_64_lay_1_rate_0_0_sched_CAWR
# lr_0_05_hdim_16_lay_1_rate_0_0_sched_Cycl
# lr_0_01_hdim_16_lay_2_rate_0_0_sched_CAWR
# lr_0_05_hdim_16_lay_2_rate_0_4_sched_CAWR
# lr_0_05_hdim_32_lay_4_rate_0_2_sched_CAWR
# lr_0_1_hdim_32_lay_2_rate_0_2_sched_CAWR
# lr_0_01_hdim_32_lay_4_rate_0_4_sched_Cycl
# lr_0_1_hdim_64_lay_1_rate_0_2_sched_Cycl
# lr_0_05_hdim_64_lay_1_rate_0_4_sched_Cycl
# lr_0_05_hdim_64_lay_4_rate_0_0_sched_CAWR
# lr_0_1_hdim_64_lay_1_rate_0_4_sched_CAWR
# lr_0_05_hdim_64_lay_2_rate_0_4_sched_CAWR
# lr_0_1_hdim_32_lay_1_rate_0_2_sched_Cycl
# lr_0_05_hdim_16_lay_1_rate_0_0_sched_CAWR
# lr_0_1_hdim_32_lay_2_rate_0_4_sched_Cycl
# lr_0_01_hdim_32_lay_1_rate_0_2_sched_Cycl
# lr_0_1_hdim_64_lay_1_rate_0_2_sched_CAWR
# lr_0_05_hdim_32_lay_2_rate_0_2_sched_Cycl
# lr_0_01_hdim_16_lay_2_rate_0_4_sched_CAWR
# lr_0_01_hdim_64_lay_2_rate_0_0_sched_Cycl
# lr_0_1_hdim_64_lay_4_rate_0_0_sched_CAWR
# lr_0_05_hdim_64_lay_2_rate_0_4_sched_Cycl
# lr_0_05_hdim_32_lay_2_rate_0_4_sched_Cycl
# lr_0_1_hdim_16_lay_1_rate_0_0_sched_Cycl
# lr_0_05_hdim_16_lay_2_rate_0_0_sched_CAWR
# lr_0_01_hdim_64_lay_1_rate_0_0_sched_Cycl
# lr_0_01_hdim_32_lay_1_rate_0_0_sched_CAWR
# lr_0_05_hdim_64_lay_4_rate_0_0_sched_Cycl
# lr_0_05_hdim_16_lay_1_rate_0_4_sched_CAWR
# lr_0_1_hdim_32_lay_4_rate_0_0_sched_CAWR
# lr_0_1_hdim_32_lay_2_rate_0_0_sched_CAWR
# lr_0_05_hdim_64_lay_2_rate_0_2_sched_CAWR
# lr_0_05_hdim_64_lay_1_rate_0_4_sched_CAWR
# lr_0_1_hdim_16_lay_4_rate_0_4_sched_CAWR
# lr_0_1_hdim_16_lay_1_rate_0_4_sched_CAWR
# lr_0_1_hdim_16_lay_4_rate_0_2_sched_Cycl
# lr_0_05_hdim_64_lay_2_rate_0_0_sched_Cycl
# lr_0_05_hdim_16_lay_4_rate_0_4_sched_CAWR
# lr_0_01_hdim_64_lay_4_rate_0_0_sched_CAWR
# lr_0_01_hdim_16_lay_4_rate_0_0_sched_CAWR
# lr_0_05_hdim_16_lay_4_rate_0_2_sched_Cycl
# lr_0_1_hdim_16_lay_4_rate_0_4_sched_Cycl
# lr_0_01_hdim_32_lay_2_rate_0_4_sched_CAWR
# lr_0_05_hdim_32_lay_1_rate_0_4_sched_CAWR
# lr_0_01_hdim_16_lay_4_rate_0_2_sched_Cycl
# lr_0_01_hdim_16_lay_4_rate_0_2_sched_CAWR
# lr_0_05_hdim_64_lay_1_rate_0_0_sched_CAWR
# lr_0_05_hdim_32_lay_2_rate_0_0_sched_CAWR
# lr_0_01_hdim_16_lay_4_rate_0_0_sched_Cycl
# lr_0_1_hdim_16_lay_2_rate_0_4_sched_Cycl
# lr_0_05_hdim_16_lay_1_rate_0_2_sched_CAWR
# lr_0_01_hdim_64_lay_1_rate_0_2_sched_Cycl
# lr_0_1_hdim_16_lay_1_rate_0_2_sched_CAWR
# lr_0_05_hdim_32_lay_1_rate_0_0_sched_CAWR
# lr_0_01_hdim_16_lay_2_rate_0_4_sched_Cycl
# lr_0_1_hdim_64_lay_2_rate_0_0_sched_Cycl
# lr_0_05_hdim_64_lay_4_rate_0_4_sched_CAWR
# lr_0_1_hdim_16_lay_4_rate_0_2_sched_CAWR
# lr_0_05_hdim_32_lay_4_rate_0_4_sched_CAWR
# lr_0_05_hdim_64_lay_2_rate_0_2_sched_Cycl
# lr_0_01_hdim_64_lay_2_rate_0_4_sched_CAWR
# lr_0_1_hdim_32_lay_2_rate_0_0_sched_Cycl
# lr_0_1_hdim_64_lay_4_rate_0_4_sched_CAWR
# lr_0_05_hdim_64_lay_1_rate_0_2_sched_Cycl
# lr_0_1_hdim_32_lay_1_rate_0_4_sched_Cycl
# lr_0_01_hdim_32_lay_4_rate_0_0_sched_CAWR
# lr_0_1_hdim_64_lay_2_rate_0_4_sched_CAWR
# lr_0_1_hdim_64_lay_4_rate_0_2_sched_Cycl
# lr_0_01_hdim_32_lay_4_rate_0_2_sched_CAWR
# lr_0_1_hdim_16_lay_2_rate_0_2_sched_Cycl
# lr_0_05_hdim_32_lay_4_rate_0_0_sched_CAWR
# lr_0_1_hdim_64_lay_2_rate_0_2_sched_CAWR
# lr_0_1_hdim_16_lay_1_rate_0_0_sched_CAWR
# lr_0_01_hdim_64_lay_4_rate_0_2_sched_CAWR
# lr_0_01_hdim_64_lay_2_rate_0_4_sched_Cycl
# lr_0_01_hdim_32_lay_1_rate_0_2_sched_CAWR
# lr_0_05_hdim_16_lay_4_rate_0_0_sched_Cycl
# lr_0_1_hdim_16_lay_2_rate_0_0_sched_CAWR
# lr_0_1_hdim_32_lay_4_rate_0_0_sched_Cycl
# lr_0_05_hdim_16_lay_1_rate_0_2_sched_Cycl
# lr_0_1_hdim_16_lay_4_rate_0_0_sched_CAWR
# lr_0_05_hdim_32_lay_1_rate_0_0_sched_Cycl
# lr_0_01_hdim_64_lay_4_rate_0_4_sched_CAWR
# lr_0_01_hdim_16_lay_2_rate_0_2_sched_CAWR
# lr_0_01_hdim_32_lay_2_rate_0_0_sched_Cycl
# lr_0_01_hdim_32_lay_1_rate_0_0_sched_Cycl
# lr_0_05_hdim_32_lay_4_rate_0_2_sched_Cycl
# lr_0_01_hdim_64_lay_4_rate_0_2_sched_Cycl
# lr_0_01_hdim_32_lay_4_rate_0_2_sched_Cycl
# lr_0_01_hdim_16_lay_4_rate_0_4_sched_CAWR
# lr_0_01_hdim_32_lay_2_rate_0_2_sched_Cycl
# lr_0_05_hdim_32_lay_4_rate_0_0_sched_Cycl
# lr_0_01_hdim_16_lay_4_rate_0_4_sched_Cycl
# lr_0_01_hdim_64_lay_4_rate_0_0_sched_Cycl
# lr_0_01_hdim_16_lay_1_rate_0_2_sched_Cycl
# lr_0_1_hdim_16_lay_2_rate_0_4_sched_CAWR
# lr_0_05_hdim_16_lay_2_rate_0_0_sched_Cycl
# lr_0_1_hdim_64_lay_4_rate_0_0_sched_Cycl
# lr_0_01_hdim_64_lay_1_rate_0_4_sched_CAWR
# lr_0_05_hdim_64_lay_4_rate_0_4_sched_Cycl
# lr_0_01_hdim_32_lay_1_rate_0_4_sched_Cycl
# lr_0_05_hdim_16_lay_2_rate_0_2_sched_CAWR
# lr_0_01_hdim_16_lay_2_rate_0_0_sched_Cycl
# lr_0_05_hdim_32_lay_1_rate_0_2_sched_Cycl
# lr_0_01_hdim_16_lay_1_rate_0_2_sched_CAWR
# lr_0_01_hdim_64_lay_4_rate_0_4_sched_Cycl
# lr_0_05_hdim_16_lay_4_rate_0_0_sched_CAWR
# lr_0_01_hdim_16_lay_1_rate_0_0_sched_CAWR
# lr_0_01_hdim_64_lay_1_rate_0_4_sched_Cycl
# lr_0_05_hdim_32_lay_4_rate_0_4_sched_Cycl
# lr_0_1_hdim_32_lay_2_rate_0_4_sched_CAWR
# lr_0_01_hdim_64_lay_2_rate_0_2_sched_Cycl
# lr_0_05_hdim_64_lay_1_rate_0_2_sched_CAWR
# lr_0_1_hdim_16_lay_2_rate_0_2_sched_CAWR
# lr_0_1_hdim_64_lay_2_rate_0_4_sched_Cycl
# lr_0_1_hdim_16_lay_1_rate_0_2_sched_Cycl
# lr_0_1_hdim_32_lay_4_rate_0_4_sched_CAWR
# lr_0_05_hdim_64_lay_4_rate_0_2_sched_CAWR
# lr_0_01_hdim_32_lay_2_rate_0_0_sched_CAWR
# lr_0_1_hdim_64_lay_4_rate_0_4_sched_Cycl
# lr_0_01_hdim_16_lay_1_rate_0_0_sched_Cycl
# lr_0_1_hdim_64_lay_2_rate_0_2_sched_Cycl
# lr_0_1_hdim_64_lay_1_rate_0_0_sched_Cycl
# lr_0_05_hdim_16_lay_4_rate_0_2_sched_CAWR
# lr_0_01_hdim_32_lay_1_rate_0_4_sched_CAWR
# lr_0_1_hdim_32_lay_4_rate_0_2_sched_CAWR
# lr_0_1_hdim_32_lay_1_rate_0_4_sched_CAWR
# lr_0_1_hdim_64_lay_4_rate_0_2_sched_CAWR
# lr_0_01_hdim_16_lay_2_rate_0_2_sched_Cycl
# lr_0_01_hdim_32_lay_2_rate_0_4_sched_Cycl
# lr_0_1_hdim_32_lay_1_rate_0_0_sched_CAWR
# lr_0_05_hdim_64_lay_1_rate_0_0_sched_Cycl
# lr_0_05_hdim_32_lay_1_rate_0_4_sched_Cycl
# lr_0_01_hdim_64_lay_2_rate_0_0_sched_CAWR
# lr_0_01_hdim_16_lay_1_rate_0_4_sched_CAWR
# lr_0_1_hdim_32_lay_4_rate_0_4_sched_Cycl
# lr_0_05_hdim_32_lay_1_rate_0_2_sched_CAWR
# lr_0_1_hdim_32_lay_4_rate_0_2_sched_Cycl
# lr_0_05_hdim_64_lay_4_rate_0_2_sched_Cycl
# lr_0_05_hdim_16_lay_4_rate_0_4_sched_Cycl
# lr_0_1_hdim_16_lay_4_rate_0_0_sched_Cycl
# lr_0_01_hdim_32_lay_4_rate_0_0_sched_Cycl
# lr_0_01_hdim_64_lay_1_rate_0_2_sched_CAWR
# lr_0_05_hdim_16_lay_2_rate_0_2_sched_Cycl
# lr_0_1_hdim_32_lay_2_rate_0_2_sched_Cycl
# lr_0_01_hdim_16_lay_1_rate_0_4_sched_Cycl
# lr_0_01_hdim_64_lay_2_rate_0_2_sched_CAWR
# lr_0_1_hdim_16_lay_1_rate_0_4_sched_Cycl
# lr_0_01_hdim_32_lay_4_rate_0_4_sched_CAWR
# lr_0_01_hdim_32_lay_2_rate_0_2_sched_CAWR
# lr_0_1_hdim_32_lay_1_rate_0_2_sched_CAWR
# lr_0_05_hdim_32_lay_2_rate_0_0_sched_Cycl
# lr_0_1_hdim_64_lay_1_rate_0_0_sched_CAWR

# %%
# each run path has a config.yaml file and a logs/training_log.csv file
# for the first 10 runs, load the config.yaml file and the training log csv
def extract_min_losses_and_hparams(exp_dir):
    losses_and_hparams = []
    for run in runs:
        path = os.path.join(exp_dir, run)
        config_path = os.path.join(path, "run_config.yml")
        log_path = os.path.join(path, "logs", "training_log.csv")
        
        with open(config_path, 'r') as stream:
            config = yaml.safe_load(stream)

        log = pd.read_csv(log_path)
        log = log[log["Total Loss"] > 0.0] # filter out 0.0-losses from non-reached epochs
        min_loss = log["Total Loss"].min()

        # the config is two layered. Extract the second layer and create a flat dictionary
        hparams = {}
        for category in config:
            c = config[category]
            for key in c:
                hparams[key] = c[key]
        losses_and_hparams.append((min_loss, hparams))
    return losses_and_hparams

losses_and_hparams = extract_min_losses_and_hparams(exp_dir)

# %%
# get relevant hyperparamters from a config dictionary
relevant_hparams = ['learning_rate', 'hidden_dim', 'n_layers', 'dropout_rate', 'scheduler', 'adaptive', 'batch_size']
def get_relevant_hparams(config, relevant_hparams):
    return {key: config[key] for key in config if key in relevant_hparams}
# tuned_hparams = get_relevant_hparams(min_run, relevant_hparams)

# %%
min_l = [loss for loss, _ in losses_and_hparams]
plt.figure(figsize=(16,5), dpi=100)
plt.bar(range(len(min_l)), min_l)
plt.xlabel("Run")
plt.ylabel("Minimum Loss")
plt.title("Minimum Losses for Runs")
# insert the minimum loss values as text above the bars
for i, v in enumerate(min_l):
    plt.text(i - 0.4, v + 0.001, str(round(v, 3)))

plt.show()

# %%
# find the run with the lowest loss
min_index = np.argmin(min_l)
# min_run = runs[min_index]
min_run = losses_and_hparams[min_index][1]
print(f"Run {min_index} with lowest loss: {min_run}")
# Out:
# Run 136 with lowest loss: {'batch_size': -1, 'num_collocation_points': 1000, 't_domain': [0, 2], 'x_domain': [-1, 1], 'n_logs': 100, 'tensorboard': False, 'amplitude': 1.0, 'sigma': 0.2, 'wave_speed': 1.0, 'x0': 0.2, 'L2_penalty': 0.005, 'adaptive': True, 'dropout_rate': 0.2, 'epochs': 3000, 'hidden_dim': 64, 'initialization': True, 'learning_rate': 0.1, 'n_layers': 4, 'optimizer': 'AdamW', 'patience': 500, 'scheduler': 'CAWR'}

# %%
# find the runs with the 10 lowest losses, their index and their config
min_indices = np.argsort(min_l)[:10]
min_losses = [min_l[i] for i in min_indices]
min_runs = [runs[i] for i in min_indices]
min_configs = [os.path.join(exp_dir, run, "run_config.yml") for run in min_runs]

# %%
losses_and_hparams
# Out:
# [(0.0522270045380164,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0073865362278307,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0495532509090262,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0532994232323072,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0391469447638618,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0583642214632353,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0205070852275792,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0287025322136184,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.050495121990201,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0470619013862105,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0349483261614197,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0294951844136644,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0864043209398968,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.03882654237914,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0916157016910916,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0941079439404292,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0432441746791491,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0516318871880142,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0571789041276996,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0629462254507727,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0579697530844815,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0348336336530498,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0375931260257325,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0498404750240257,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0611200101571934,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.09226493548779,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.042888752262233,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0942064373333789,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0118441760891268,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.2220195730147831,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0430196794562071,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0471338769337681,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0218853224559709,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0368246761936329,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.020832551037253,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0525585474061993,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0211799583234414,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0801273632928956,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0914924607076908,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0475807274477752,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0643488978758518,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.089427850517075,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0939303224000878,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0836263443878608,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0359358961957804,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0088877567347723,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0872238744008457,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0440349312795529,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0279158159657826,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0526523259863747,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0931786841159766,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.066534105410098,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0903056563640734,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0749593743164988,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0425304537091746,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0745570130071569,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0433608523560878,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0194118985310035,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0603436164601144,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0686287049465262,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0445121831312596,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0405370494348972,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0367067717959375,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0812316247753038,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0138119801755832,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0964301106765296,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.061664458242009,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0975154385877779,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0315721868831883,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0461352907735159,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0286366278894362,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0908514624586912,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0476646964327727,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0442165808286893,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0359694306788863,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0999343608955374,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.042662703733215,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0338372235705417,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0391998999806371,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0390138987053776,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.1102580639267275,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.038545966026392,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0417002708868488,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0848380237008447,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0413191557682887,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0374250607287193,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0877909543575426,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0336652482580311,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0468092264707264,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0550676629172685,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0154608544032647,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0477099736048256,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0427061733600115,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0041455287486101,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0300735619924162,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0459780929022196,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0471120991952648,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0492820052099114,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
# ...
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0345622715745702,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0292537210166073,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0807934365731967,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0785049146206917,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0767351227740907,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0772196176862068,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (8.085420925266651e-07,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0666346823853815,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0662869848264543,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0528480008377669,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.012145289898587,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0521593598897898,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0154229106749885,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0803721405459265,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.100256079791902,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0375030762010197,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0515691112107548,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0415357718028572,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.091487203030324,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0420246516706276,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0068014277406833,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0480841717903374,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0400468948874302,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0327076364492453,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0713606482625636,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0643775764320301,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0552725559457576,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 16,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.091200294149025,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.4,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 4,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0436841139192716,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.01,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0470665526520239,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.2,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'}),
#  (0.0070906399374466,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 32,
#    'initialization': True,
#    'learning_rate': 0.05,
#    'n_layers': 2,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'Cycl'}),
#  (0.0748512274651,
#   {'batch_size': -1,
#    'num_collocation_points': 1000,
#    't_domain': [0, 2],
#    'x_domain': [-1, 1],
#    'n_logs': 100,
#    'tensorboard': False,
#    'amplitude': 1.0,
#    'sigma': 0.2,
#    'wave_speed': 1.0,
#    'x0': 0.2,
#    'L2_penalty': 0.005,
#    'adaptive': True,
#    'dropout_rate': 0.0,
#    'epochs': 3000,
#    'hidden_dim': 64,
#    'initialization': True,
#    'learning_rate': 0.1,
#    'n_layers': 1,
#    'optimizer': 'AdamW',
#    'patience': 500,
#    'scheduler': 'CAWR'})]

# %%
min_losses
# Out:
# [8.085420925266651e-07,
#  0.0021047470785895,
#  0.0041455287486101,
#  0.0046332060617224,
#  0.0068014277406833,
#  0.0070906399374466,
#  0.0073865362278307,
#  0.0088877567347723,
#  0.0118441760891268,
#  0.012145289898587]

# %%
# horizontal bar chart of the 10 runs with the lowest losses
plt.figure(figsize=(8,6), dpi=100)
plt.barh(range(len(min_losses)), min_losses)
plt.xlabel("Minimum Loss")
plt.xscale("log")
plt.ylabel("Run")
# insert the minimum loss values as text next to the bars
for i, v in enumerate(min_losses):
    plt.text(v, i - 0.1, f"{v:.2e}")
# plt.xlim(0, max(min_losses) * 1.1)
# insert name of the run as y-tick labels
plt.yticks(range(len(min_runs)), min_runs)


plt.title(f"10 best run configs by loss. BS: {1}, Adaptive: false")
plt.show()

# %%
# we need to know the effect that each hyperparameter value has on the average loss over all runs
def aggregate_hparam_effect(losses_and_hparams):
    hparam_effects = {}  # Dictionary to store the average loss for each hyperparameter value

    for loss, hparams in losses_and_hparams:
        for hparam, value in hparams.items():
            if hparam not in hparam_effects:
                hparam_effects[hparam] = {}
            try:
                if value not in hparam_effects[hparam]:
                    hparam_effects[hparam][value] = []
            except:
                print(hparam, value)


            hparam_effects[hparam][value].append(loss)

    # Calculating average losses
    for hparam in hparam_effects:
        for value in hparam_effects[hparam]:
            hparam_effects[hparam][value] = np.mean(hparam_effects[hparam][value])

    return hparam_effects

losses_and_tuned_hparams = []
for loss, hparams in losses_and_hparams:
    losses_and_tuned_hparams += [(loss, get_relevant_hparams(hparams, relevant_hparams))]

hparam_effects = aggregate_hparam_effect(losses_and_tuned_hparams)

# %%
hparam_effects
# Out:
# {'batch_size': {-1: 0.05447602216250121},
#  'adaptive': {True: 0.05447602216250121},
#  'dropout_rate': {0.4: 0.07415835516814287,
#   0.0: 0.03756557764340073,
#   0.2: 0.05170413367596002},
#  'hidden_dim': {32: 0.05208125424938385,
#   16: 0.05628824145566638,
#   64: 0.055058570782453395},
#  'learning_rate': {0.05: 0.0535153916381588,
#   0.1: 0.05893581125309212,
#   0.01: 0.050976863596252704},
#  'n_layers': {2: 0.04853286761480721,
#   1: 0.05237205494798133,
#   4: 0.06252314392471509},
#  'scheduler': {'CAWR': 0.06402920442234596, 'Cycl': 0.044922839902656456}}

# %%
for hparam in hparam_effects:
    hparam_values = list(hparam_effects[hparam].keys())
    avg_losses = list(hparam_effects[hparam].values())

    plt.figure(figsize=(10, 6))
    plt.bar(range(len(hparam_values)), avg_losses)
    plt.xticks(range(len(hparam_values)), hparam_values)
    plt.xlabel('Value')
    plt.ylabel('Average Loss')
    plt.title(f'Effect of {hparam} on Average Loss')
    plt.show()
